# %%
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import MetaTrader5 as mt5
import plotly.express as px

# %%
# display data on the MetaTrader 5 package
print("MetaTrader5 package author: ",mt5.__author__)
print("MetaTrader5 package version: ",mt5.__version__)

if not mt5.initialize(login=121391564, server="Exness-MT5Trial7",password="Pc9874123"):
    print("initialize() failed, error code =",mt5.last_error())
    quit()

# display data on connection status, server name and trading account
print(mt5.terminal_info())
# display data on MetaTrader 5 version
print(mt5.version())
 
# shut down connection to the MetaTrader 5 terminal
mt5.shutdown()
# Out:
# MetaTrader5 package author:  MetaQuotes Ltd.
# MetaTrader5 package version:  5.0.45
# TerminalInfo(community_account=False, community_connection=False, connected=True, dlls_allowed=False, trade_allowed=False, tradeapi_disabled=False, email_enabled=False, ftp_enabled=False, notifications_enabled=False, mqid=True, build=3800, maxbars=100000, codepage=0, ping_last=34865, community_balance=0.0, retransmission=0.0, company='MetaQuotes Software Corp.', name='MetaTrader 5', language='English', path='C:\\Program Files\\MetaTrader 5', data_path='C:\\Users\\User\\AppData\\Roaming\\MetaQuotes\\Terminal\\D0E8209F77C8CF37AD8BF550E51FF075', commondata_path='C:\\Users\\User\\AppData\\Roaming\\MetaQuotes\\Terminal\\Common')
# (500, 3800, '8 Jun 2023')
# True

# %%
mt5.initialize()
# Out:
# True

# %%
login = 121391564
password = 'xxxxxxx'
server = 'Exness-MT5Trial7'

mt5.login(login, password, server)
# Out:
# True

# %%
print('Account :', mt5.account_info().login)
print('Balance :', mt5.account_info().balance)
print('Equity :', mt5.account_info().equity)
# Out:
# Account : 121391564
# Balance : 1000.18
# Equity : 1014.27

# %%
print(mt5.symbols_total())
# Out:
# 344

# %%
price_15m = pd.DataFrame(mt5.copy_rates_range("XAUUSD",
                                          mt5.TIMEFRAME_M15,
                                          datetime(2023, 6, 1),
                                          datetime.now()))

fig = px.line(price_15m, x = price_15m['time'], y = price_15m['close'])
fig.show()

price_15m
# Out:
#            time      open      high       low     close  tick_volume  spread  \
# 0    1685552400  1965.212  1966.357  1964.634  1965.617          866      62
# 1    1685553300  1965.615  1966.008  1963.355  1963.692         1517      62
# 2    1685554200  1963.662  1968.124  1963.139  1968.028         1441      62
# 3    1685555100  1968.062  1968.760  1966.215  1966.257         1207      62
# 4    1685556000  1966.273  1967.116  1966.142  1967.116         1041      62
# ..          ...       ...       ...       ...       ...          ...     ...
# 601  1686291300  1964.235  1965.314  1964.235  1965.014          934      62
# 602  1686292200  1965.049  1965.469  1964.393  1965.118          950      62
# 603  1686293100  1965.112  1966.101  1964.692  1965.731         1091      62
# 604  1686294000  1965.714  1965.718  1964.212  1964.526         1204      62
# 605  1686294900  1964.498  1964.584  1964.214  1964.367          138      62
#
#      real_volume
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 601            0
# 602            0
# 603            0
# 604            0
# 605            0
#
# [606 rows x 8 columns]

# %%
price_1d = pd.DataFrame(mt5.copy_rates_range("XAUUSD",
                                             mt5.TIMEFRAME_D1,
                                             datetime(2023,5,1),
                                             datetime.now()))
fig2 = px.line(price_1d, x = price_1d['time'], y = price_1d['close'])
fig2.show()

# %%
mt5.orders_get()
# Out:
# ()

# %%
mt5.positions_total()
# Out:
# 2

# %%
mt5.positions_get()
# Out:
# (TradePosition(ticket=135012857, time=1686274804, time_msc=1686274804265, time_update=1686274804, time_update_msc=1686274804265, type=1, magic=0, identifier=135012857, reason=0, volume=0.3, price_open=1964.7160000000001, sl=1970.52, tp=1941.352, price_current=1964.409, swap=0.0, profit=9.21, symbol='XAUUSD', comment='', external_id=''),
#  TradePosition(ticket=135163143, time=1686292212, time_msc=1686292212657, time_update=1686292212, time_update_msc=1686292212657, type=1, magic=234000, identifier=135163143, reason=3, volume=0.1, price_open=1964.733, sl=0.0, tp=0.0, price_current=1964.409, swap=0.0, profit=3.24, symbol='XAUUSD', comment='Python Script Op', external_id=''))

# %%
mt5.history_orders_get(datetime(2023,5,1), datetime.now())
# Out:
# (TradeOrder(ticket=134117656, time_setup=1686203384, time_setup_msc=1686203384832, time_done=1686203384, time_done_msc=1686203384931, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=134117656, position_by_id=0, reason=0, volume_initial=0.01, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1946.534, price_stoplimit=0.0, symbol='XAUUSD', comment='', external_id=''),
#  TradeOrder(ticket=134118282, time_setup=1686203449, time_setup_msc=1686203449931, time_done=1686203450, time_done_msc=1686203450025, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=134117656, position_by_id=0, reason=0, volume_initial=0.01, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1947.001, price_stoplimit=0.0, symbol='XAUUSD', comment='', external_id=''),
#  TradeOrder(ticket=134118386, time_setup=1686203460, time_setup_msc=1686203460453, time_done=1686203460, time_done_msc=1686203460547, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=134118386, position_by_id=0, reason=0, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1947.018, price_stoplimit=0.0, symbol='XAUUSD', comment='', external_id=''),
#  TradeOrder(ticket=134154936, time_setup=1686206185, time_setup_msc=1686206185266, time_done=1686206185, time_done_msc=1686206185273, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=134118386, position_by_id=0, reason=4, volume_initial=0.1, volume_current=0.0, price_open=1945.0, sl=0.0, tp=0.0, price_current=1945.0, price_stoplimit=0.0, symbol='XAUUSD', comment='[sl 1945.000]', external_id=''),
#  TradeOrder(ticket=134161802, time_setup=1686206645, time_setup_msc=1686206645392, time_done=1686206645, time_done_msc=1686206645440, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=134161802, position_by_id=0, reason=1, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=139.817, price_stoplimit=0.0, symbol='USDJPY', comment='', external_id=''),
#  TradeOrder(ticket=134164569, time_setup=1686206866, time_setup_msc=1686206866332, time_done=1686206866, time_done_msc=1686206866381, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=134164569, position_by_id=0, reason=1, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=139.806, price_stoplimit=0.0, symbol='USDJPY', comment='', external_id=''),
#  TradeOrder(ticket=134171504, time_setup=1686207393, time_setup_msc=1686207393288, time_done=1686207393, time_done_msc=1686207393362, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=134171504, position_by_id=0, reason=1, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.10183, price_stoplimit=0.0, symbol='AUDNZD', comment='', external_id=''),
#  TradeOrder(ticket=134174153, time_setup=1686207608, time_setup_msc=1686207608439, time_done=1686207608, time_done_msc=1686207608531, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=134174153, position_by_id=0, reason=1, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.10174, price_stoplimit=0.0, symbol='AUDNZD', comment='', external_id=''),
#  TradeOrder(ticket=134217611, time_setup=1686210954, time_setup_msc=1686210954320, time_done=1686210954, time_done_msc=1686210954366, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=134217611, position_by_id=0, reason=1, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=139.751, price_stoplimit=0.0, symbol='USDJPY', comment='', external_id=''),
#  TradeOrder(ticket=134246009, time_setup=1686213317, time_setup_msc=1686213317316, time_done=1686213317, time_done_msc=1686213317322, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=134161802, position_by_id=0, reason=4, volume_initial=0.1, volume_current=0.0, price_open=139.688, sl=0.0, tp=0.0, price_current=139.688, price_stoplimit=0.0, symbol='USDJPY', comment='[sl 139.688]', external_id=''),
#  TradeOrder(ticket=134246010, time_setup=1686213317, time_setup_msc=1686213317317, time_done=1686213317, time_done_msc=1686213317320, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=134164569, position_by_id=0, reason=4, volume_initial=0.1, volume_current=0.0, price_open=139.688, sl=0.0, tp=0.0, price_current=139.688, price_stoplimit=0.0, symbol='USDJPY', comment='[sl 139.688]', external_id=''),
#  TradeOrder(ticket=134246011, time_setup=1686213317, time_setup_msc=1686213317317, time_done=1686213317, time_done_msc=1686213317321, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=134217611, position_by_id=0, reason=4, volume_initial=0.1, volume_current=0.0, price_open=139.688, sl=0.0, tp=0.0, price_current=139.688, price_stoplimit=0.0, symbol='USDJPY', comment='[sl 139.688]', external_id=''),
#  TradeOrder(ticket=134572236, time_setup=1686231394, time_setup_msc=1686231394274, time_done=1686231394, time_done_msc=1686231394343, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=134174153, position_by_id=0, reason=0, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.10115, price_stoplimit=0.0, symbol='AUDNZD', comment='', external_id=''),
#  TradeOrder(ticket=134572369, time_setup=1686231394, time_setup_msc=1686231394804, time_done=1686231394, time_done_msc=1686231394886, time_expiration=0, type=0, type_time=0, type_filling=1, state=4, magic=0, position_id=134171504, position_by_id=0, reason=0, volume_initial=0.1, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1.10115, price_stoplimit=0.0, symbol='AUDNZD', comment='', external_id=''),
#  TradeOrder(ticket=135012857, time_setup=1686274804, time_setup_msc=1686274804250, time_done=1686274804, time_done_msc=1686274804265, time_expiration=0, type=1, type_time=0, type_filling=1, state=4, magic=0, position_id=135012857, position_by_id=0, reason=0, volume_initial=0.3, volume_current=0.0, price_open=0.0, sl=0.0, tp=0.0, price_current=1964.716, price_stoplimit=0.0, symbol='XAUUSD', comment='', external_id=''))

# %%
request = {
    "action" : mt5.TRADE_ACTION_DEAL,
    "symbol" : "XAUUSD",
    "volume" : 0.1,
    "type" : mt5.ORDER_TYPE_SELL,
    "price" : mt5.symbol_info_tick("XAUUSD").ask,
    "sl" : 0.0,
    "tp" : 0.0,
    "deviation" : 100,
    "magic" : 234000,
    "comment" : "Python Script Open",
    "type_time" : mt5.ORDER_TIME_GTC,
    "type_filling" : mt5.ORDER_FILLING_IOC
}

order = mt5.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10009, deal=72050655, order=135163143, volume=0.1, price=1964.733, bid=1964.733, ask=1964.796, comment='Python Script Op', request_id=1008909924, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='XAUUSD', volume=0.1, price=1964.796, stoplimit=0.0, sl=0.0, tp=0.0, deviation=100, type=1, type_filling=1, type_time=0, expiration=0, comment='Python Script Open', position=0, position_by=0))

# %%
positions = mt5.positions_get()
if positions:
    pos_df = pd.DataFrame(positions, columns=positions[0]._asdict().keys())
    exposure = pos_df['volume'].sum()
exposure
# Out:
# 0.4

# %%
pos_df
# Out:
#       ticket        time       time_msc  time_update  time_update_msc  type  \
# 0  135012857  1686274804  1686274804265   1686274804    1686274804265     1
# 1  135163143  1686292212  1686292212657   1686292212    1686292212657     1
#
#     magic  identifier  reason  volume  price_open       sl        tp  \
# 0       0   135012857       0     0.3    1964.716  1970.52  1941.352
# 1  234000   135163143       3     0.1    1964.733     0.00     0.000
#
#    price_current  swap  profit  symbol           comment external_id
# 0       1964.469   0.0    7.41  XAUUSD
# 1       1964.469   0.0    2.64  XAUUSD  Python Script Op

# %%
positionID = mt5.positions_get()[1][0]

# %%
request = {
    "action" : mt5.TRADE_ACTION_DEAL,
    "symbol" : "XAUUSD",
    "volume" : 0.1,
    "type" : mt5.ORDER_TYPE_BUY,
    "position" : positionID, 
    "price" : mt5.symbol_info_tick("XAUUSD").bid,
    "sl" : 0.0,
    "tp" : 0.0,
    "deviation" : 100,
    "magic" : 234000,
    "comment" : "Python Script Open",
    "type_time" : mt5.ORDER_TIME_GTC,
    "type_filling" : mt5.ORDER_FILLING_IOC
}

order = mt5.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10009, deal=72050116, order=135162166, volume=0.1, price=1964.832, bid=1964.77, ask=1964.832, comment='Python Script Op', request_id=1008909923, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='XAUUSD', volume=0.1, price=1964.77, stoplimit=0.0, sl=0.0, tp=0.0, deviation=100, type=0, type_filling=1, type_time=0, expiration=0, comment='Python Script Open', position=135156341, position_by=0))
